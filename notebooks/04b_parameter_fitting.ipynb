# %% [markdown]
# # Use-case B — homogeneous vs. heterogeneous parameter fitting
#
# 4.2 Parameter exploration and inference
#
# Leon Stefanovski (Charité University Medicine Berlin)
# Marius Pille (Berlin Institute of Health at Charité University
# Medicine)
# Leon Martin (Berlin Institute of Health at Charité University Medicine)
#
# ## Goals
#
# -   TODO: fit a global parameter to a target observable (e.g. frequency
#     gradient)
# -   TODO: fit region-wise heterogeneous parameters with TVB-Optim
# -   TODO: compare goodness of fit and interpretability
#
# ## Setup

# %%
# TODO: imports, including tvboptim

# %% [markdown]
# ## Define target and loss

# %%
# TODO: load TVBase map, define loss against simulated observable

# %% [markdown]
# ## Homogeneous fit

# %%
# TODO: optimise a single global parameter

# %% [markdown]
# ## Heterogeneous fit

# %%
# TODO: optimise a per-region parameter vector

# %% [markdown]
# ## Compare

# %%
# TODO: residuals, parameter maps, runtime

# %% [markdown]
# ## Exercises
#
# -   TODO: regularise the heterogeneous fit and discuss the trade-off
# -   TODO: try a different target map
