# %% [markdown]
# # Use-case A — Alzheimer’s disease
#
# 4.1 Parameter exploration and inference
#
# Leon Stefanovski (Charité University Medicine Berlin)
# Marius Pille (Berlin Institute of Health at Charité University
# Medicine)
# Leon Martin (Berlin Institute of Health at Charité University Medicine)
#
# ## Goals
#
# -   TODO: integrate biomedical data (e.g. amyloid / tau PET) into a TVB
#     model
# -   TODO: run a mechanistic simulation of disease progression
# -   TODO: compare healthy vs. patient-specific dynamics
#
# ## Setup

# %%
# TODO: imports

# %% [markdown]
# ## Load patient data

# %%
# TODO: connectome + per-region biomarker maps

# %% [markdown]
# ## Map biomarkers onto model parameters

# %%
# TODO: parameterise a region-specific local model

# %% [markdown]
# ## Simulate and compare

# %%
# TODO: run healthy + patient simulations, contrast outputs

# %% [markdown]
# ## Exercises
#
# -   TODO: which biomarker has the strongest effect on global dynamics?
# -   TODO: how robust is the result to the chosen mapping?
